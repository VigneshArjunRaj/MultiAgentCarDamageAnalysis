# %%
from Graph import graph

from langchain_core.runnables.graph import MermaidDrawMethod


from IPython.display import Image, display

# %%
display(
    Image(
        graph.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
print(graph.get_graph())
# Out:
# Graph(nodes={'__start__': Node(id='__start__', name='__start__', data=<class 'langchain_core.utils.pydantic.LangGraphInput'>, metadata=None), 'ReviewerBot': Node(id='ReviewerBot', name='ReviewerBot', data=ReviewerBot(tags=None, recurse=True, func_accepts_config=False, func_accepts={'writer': False, 'store': False}), metadata=None), 'CheckDamage': Node(id='CheckDamage', name='CheckDamage', data=CheckDamage(tags=None, recurse=True, func_accepts_config=False, func_accepts={'writer': False, 'store': False}), metadata=None), 'CheckParts': Node(id='CheckParts', name='CheckParts', data=CheckParts(tags=None, recurse=True, func_accepts_config=False, func_accepts={'writer': False, 'store': False}), metadata=None), 'CheckIfCar': Node(id='CheckIfCar', name='CheckIfCar', data=CheckIfCar(tags=None, recurse=True, func_accepts_config=False, func_accepts={'writer': False, 'store': False}), metadata=None), 'GeneralConversation': Node(id='GeneralConversation', name='GeneralConversation', data=GeneralConversation(tags=None, recurse=True, func_accepts_config=False, func_accepts={'writer': False, 'store': False}), metadata=None), 'HallucinationAndReviewer': Node(id='HallucinationAndReviewer', name='HallucinationAndReviewer', data=HallucinationAndReviewer(tags=None, recurse=True, func_accepts_config=False, func_accepts={'writer': False, 'store': False}), metadata=None), 'WebSearch': Node(id='WebSearch', name='WebSearch', data=WebSearch(tags=None, recurse=True, func_accepts_config=False, func_accepts={'writer': False, 'store': False}), metadata=None), 'GeneralWebSearch': Node(id='GeneralWebSearch', name='GeneralWebSearch', data=GeneralWebSearch(tags=None, recurse=True, func_accepts_config=False, func_accepts={'writer': False, 'store': False}), metadata=None), '__end__': Node(id='__end__', name='__end__', data=<class 'langchain_core.utils.pydantic.LangGraphOutput'>, metadata=None)}, edges=[Edge(source='CheckDamage', target='CheckParts', data=None, conditional=False), Edge(source='CheckParts', target='WebSearch', data=None, conditional=False), Edge(source='GeneralConversation', target='__end__', data=None, conditional=False), Edge(source='GeneralWebSearch', target='GeneralConversation', data=None, conditional=False), Edge(source='HallucinationAndReviewer', target='__end__', data=None, conditional=False), Edge(source='ReviewerBot', target='HallucinationAndReviewer', data=None, conditional=False), Edge(source='WebSearch', target='ReviewerBot', data=None, conditional=False), Edge(source='__start__', target='GeneralWebSearch', data='General', conditional=True), Edge(source='__start__', target='CheckIfCar', data='Images', conditional=True), Edge(source='CheckIfCar', target='GeneralWebSearch', data='General', conditional=True), Edge(source='CheckIfCar', target='CheckDamage', data=None, conditional=True)])
